# %% [markdown]
# <a href="https://colab.research.google.com/github/OmarMKZ/Internship/blob/main/Omar_Mostafa_EDA_1st.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
data = pd.read_csv("/content/first inten project.csv")

print(data)
# Out:
#       Booking_ID  number of adults  number of children  \
# 0       INN00001                 1                   1
# 1       INN00002                 1                   0
# 2       INN00003                 2                   1
# 3       INN00004                 1                   0
# 4       INN00005                 1                   0
# ...          ...               ...                 ...
# 36280   INN36282                 2                   0
# 36281   INN36283                 2                   0
# 36282   INN36284                 2                   0
# 36283   INN36285                 3                   0
# 36284   INN36286                 2                   0
#
#        number of weekend nights  number of week nights  type of meal  \
# 0                             2                      5   Meal Plan 1
# 1                             1                      3  Not Selected
# 2                             1                      3   Meal Plan 1
# ...

# %%
data.head(10)
# Out:
#   Booking_ID  number of adults  number of children  number of weekend nights  \
# 0   INN00001                 1                   1                         2
# 1   INN00002                 1                   0                         1
# 2   INN00003                 2                   1                         1
# 3   INN00004                 1                   0                         0
# 4   INN00005                 1                   0                         1
# 5   INN00006                 1                   0                         0
# 6   INN00007                 1                   1                         1
# 7   INN00008                 3                   0                         1
# 8   INN00009                 1                   1                         0
# 9   INN00010                 2                   0                         0
#
#    number of week nights  type of meal  car parking space    room type  \
# ...

# %%
print("Number of Entries: " + str(data.shape[0]))
# Out:
# Number of Entries: 36285

# %%
print(f"Average number of week nights booked is {data['number of week nights'].mean():.1f} nights")
# Out:
# Average number of week nights booked is 2.2 nights

# %%
print(f"Total Number of adults is {str(sum(data["number of adults"]))}\nTotal Number of children is {str(sum(data["number of children"]))}")
# Out:
# Total Number of adults is 66940
# Total Number of children is 3823

# %%
data.describe()
# Out:
#        number of adults  number of children  number of weekend nights  \
# count      36285.000000        36285.000000              36285.000000
# mean           1.844839            0.105360                  0.810693
# std            0.518813            0.402704                  0.870590
# min            0.000000            0.000000                  0.000000
# 25%            2.000000            0.000000                  0.000000
# 50%            2.000000            0.000000                  1.000000
# 75%            2.000000            0.000000                  2.000000
# max            4.000000           10.000000                  7.000000
#
#        number of week nights  car parking space     lead time      repeated  \
# count           36285.000000       36285.000000  36285.000000  36285.000000
# mean                2.204602           0.030977     85.239851      0.025630
# std                 1.410946           0.173258     85.938796      0.158032
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36285 entries, 0 to 36284
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Booking_ID                36285 non-null  object
#  1   number of adults          36285 non-null  int64
#  2   number of children        36285 non-null  int64
#  3   number of weekend nights  36285 non-null  int64
#  4   number of week nights     36285 non-null  int64
#  5   type of meal              36285 non-null  object
#  6   car parking space         36285 non-null  int64
#  7   room type                 36285 non-null  object
#  8   lead time                 36285 non-null  int64
#  9   market segment type       36285 non-null  object
#  10  repeated                  36285 non-null  int64
#  11  P-C                       36285 non-null  int64
#  12  P-not-C                   36285 non-null  int64
# ...

# %%
data.columns
# Out:
# Index(['Booking_ID', 'number of adults', 'number of children',
#        'number of weekend nights', 'number of week nights', 'type of meal',
#        'car parking space', 'room type', 'lead time', 'market segment type',
#        'repeated', 'P-C', 'P-not-C', 'average price ', 'special requests',
#        'date of reservation', 'booking status'],
#       dtype='object')

# %%
data.drop("Booking_ID",axis=1).max()
# Out:
# number of adults                       4
# number of children                    10
# number of weekend nights               7
# number of week nights                 17
# type of meal                Not Selected
# car parking space                      1
# room type                    Room_Type 7
# lead time                            443
# market segment type               Online
# repeated                               1
# P-C                                   13
# P-not-C                               58
# average price                      540.0
# special requests                       5
# date of reservation             9/9/2018
# booking status              Not_Canceled
# dtype: object

# %%
data.sort_values(by="number of adults",ascending=False)
# Out:
#       Booking_ID  number of adults  number of children  \
# 23366   INN23367                 4                   0
# 17359   INN17360                 4                   0
# 14046   INN14047                 4                   0
# 372     INN00373                 4                   0
# 657     INN00658                 4                   0
# ...          ...               ...                 ...
# 26895   INN26896                 0                   2
# 26931   INN26932                 0                   2
# 28782   INN28783                 0                   2
# 27529   INN27530                 0                   2
# 27766   INN27767                 0                   2
#
#        number of weekend nights  number of week nights type of meal  \
# 23366                         0                      1  Meal Plan 1
# 17359                         2                      1  Meal Plan 1
# 14046                         2                      1  Meal Plan 1
# ...

# %%
data.sort_values(by="average price ",ascending=False)
# Out:
#       Booking_ID  number of adults  number of children  \
# 33114   INN33115                 2                   0
# 9461    INN09462                 3                   0
# 20900   INN20901                 2                   1
# 34306   INN34307                 2                   2
# 14773   INN14774                 2                   2
# ...          ...               ...                 ...
# 33186   INN33187                 1                   0
# 21550   INN21551                 2                   0
# 21585   INN21586                 1                   0
# 21568   INN21569                 1                   0
# 4509    INN04510                 1                   0
#
#        number of weekend nights  number of week nights type of meal  \
# 33114                         0                      1  Meal Plan 1
# 9461                          0                      2  Meal Plan 1
# 20900                         1                      2  Meal Plan 2
# ...

# %%
data.duplicated(subset="Booking_ID")
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 36280    False
# 36281    False
# 36282    False
# 36283    False
# 36284    False
# Length: 36285, dtype: bool

# %%
sum(data.duplicated(subset="Booking_ID"))
# Out:
# 0

# %%
print(data.isnull().sum())
# Out:
# Booking_ID                  0
# number of adults            0
# number of children          0
# number of weekend nights    0
# number of week nights       0
# type of meal                0
# car parking space           0
# room type                   0
# lead time                   0
# market segment type         0
# repeated                    0
# P-C                         0
# P-not-C                     0
# average price               0
# special requests            0
# date of reservation         0
# booking status              0
# dtype: int64

# %% [markdown]
# # Notes
# **Handle Null values**
#
#
# ```
# data("<column>".fillna("<dtype>"))
# data("<column>".dropna())
# data("<column>") = data("<column>").replace("",<>)
# # one hot encoding and label encoding
# ```

# %%
sns.boxplot(data=data['average price '], palette="rainbow",orient="h")
# Out:
# /tmp/ipython-input-2846503511.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data['average price '], palette="rainbow",orient="h")
# <Axes: xlabel='average price '>

# %%
sns.boxplot(data=data['lead time'], palette="rainbow",orient="h")
# Out:
# /tmp/ipython-input-2617889844.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data['lead time'], palette="rainbow",orient="h")
# <Axes: xlabel='lead time'>

# %%
sns.displot(data=data['average price '], color='red')

# %%
sns.distplot(data['average price '])
# Out:
# /tmp/ipython-input-1763198521.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['average price '])
# <Axes: xlabel='average price ', ylabel='Density'>

# %%
sns.jointplot(x="number of adults", y="average price ",data=data)

# %%
sns.jointplot(x="number of adults", y="average price ",data=data, kind="hex")

# %%
sns.pairplot(data)

# %%
sns.barplot(data=data, x="number of adults",y="average price ")
# Out:
# <Axes: xlabel='number of adults', ylabel='average price '>

# %%
sns.boxplot(data=data, palette="rainbow", orient="h")
# Out:
# <Axes: >
